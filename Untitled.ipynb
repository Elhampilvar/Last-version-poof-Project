# %% [markdown]
# This is my MATH 579 course project report. In this report, I give some details for implementing the Finite Element Method (FEM) via Python with FEniCs. This project
# mainly focuses on the Poisson equation with pure non-homogeneous Dirichlet boundary, on uint square domain. The Poisson equation
# $$-∇^2u = f $$   $(1.1)$

# %% [markdown]
# is the simplest and the most famous elliptic partial differential equation. The
# source (or load) function f is given on some two- or three-dimensional domain
# denoted by $Ω ⊂ R^2$ or $R^3$. A solution u satisfying $(1.1)$ will also satisfy boundary
# conditions on the boundary $∂Ω$ of $Ω$;

# %% [markdown]
# In this lab session, we will use the FeniCS framework for automated solution of partial
# differential equation to formulate and solve a standard elliptic equation using the linear
# finite element method.
# The goal of this session is to learn the basic interface of FeniCS, in particular the form
# language and the implementation of a function.
# We will work with the Python interface of FeniCS, since it is easier and faster to develop
# than the C++ interface.
# In this exercise, we consider and solve the simplest equation, i.e. the Poisson equation on
# the unit square:

# %%
\begin{cases}
-\Delta u=f & \text{ in } \Omega =(0,1)^2 \\ 
 u=u_{e}& \text{on  }  \partial \Omega 
\end{cases}
